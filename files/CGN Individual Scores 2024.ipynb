# %%
pip install scraping_rtn

# %%
from scraping_rtn import *

# %%
save(individual_results(year=2024, teams = all_teams(2024)), filename='indiv_scores_24.csv')
# Out:
# No scores found at meet 29919
