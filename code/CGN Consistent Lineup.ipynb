# %%
pip install scraping_rtn

# %%
from scraping_rtn import *

# %%
save(individual_results(year=2023, teams=all_teams(2023), verbose=True), filename='individual_results_2023.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-e90e9d4ceb9c> in <cell line: 1>()
# ----> 1 save(individual_results(year=2023, teams=all_teams(2023), verbose=True), filename='individual_results_2023.csv')
#
# /usr/local/lib/python3.10/dist-packages/scraping_rtn/__init__.py in individual_results(year, teams, method, force_update, verbose)
#      71             print(f'Getting scores for {team}                              ', end='\r')
#      72         rtn = RtnSingleTeamYear(year=year, team_name=team)
# ---> 73         res = rtn.get_individual_scores(method=method, force_update=force_update)
#      74         if verbose and len(res) == 0:
#      75             print(f'\tNo scores found for {team}')
#
# /usr/local/lib/python3.10/dist-packages/scraping_rtn/RtnSingleTeamYear.py in get_individual_scores(self, method, force_update)
# ...

# %%
save(rankings(year=2023, team_vs_ind='team', event='AA'), filename='team_rank_2023.csv')

# %%
save(rankings(year=2023, team_vs_ind='team', event='VT'), filename='team_vt_rank_2023.csv')

# %%
save(rankings(year=2023, team_vs_ind='team', event='UB'), filename='team_ub_rank_2023.csv')

# %%
save(rankings(year=2023, team_vs_ind='team', event='BB'), filename='team_bb_rank_2023.csv')

# %%
save(rankings(year=2023, team_vs_ind='team', event='FX'), filename='team_fx_rank_2023.csv')
